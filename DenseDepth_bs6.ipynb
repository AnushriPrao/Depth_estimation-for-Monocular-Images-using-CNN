# %% [markdown]
# # Download Train and Test data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Dense_depth
# Out:
# /content/drive/My Drive/Dense_depth

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /content/drive/My Drive/Dense_depth

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_data.zip
# !unzip nyu_data.zip

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_test.zip

# %% [markdown]
# # Set Paths

# %%
import os
DATA_PATH = '/content/drive/MyDrive/Dense_depth/'
SAVE_PATH = '/content/drive/MyDrive/Dense_depth'
#os.chdir(SAVE_PATH)
os.getcwd()
# Out:
# '/content/drive/My Drive/Dense_depth'

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Loss function

# %%
def depth_loss(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    # Point-wise depth
    l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    # Edges
    dy_true, dx_true = tf.image.image_gradients(y_true)
    dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    l_edges = K.mean(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)

    # Structural similarity (SSIM) index
    l_ssim = K.clip((1 - tf.image.ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    return (w1 * l_ssim) + (w2 * K.mean(l_edges)) + (w3 * K.mean(l_depth))

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear')
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3) ,include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %% [markdown]
# ## Decode Block

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %% [markdown]
# ## Combining Encoder and Decoder

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

# %% [markdown]
# # Data Loader

# %%
import tensorflow as tf

from sklearn.utils import shuffle

class DataLoader():
    def __init__(self, csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', DEBUG=False, NUMBER_DATA=None, split_ratio=5):
        self.shape_rgb = (480, 640, 3)
        self.shape_depth = (240, 320, 1)
        self.split_ratio = split_ratio
        self.read_data(csv_file, DEBUG=DEBUG, num_images=NUMBER_DATA)

    def nyu_resize(self, img, resolution=480, padding=6):
        from skimage.transform import resize
        return resize(img, (resolution, int(resolution*4/3)), preserve_range=True, mode='reflect', anti_aliasing=True )

    def read_data(self, csv_file, DEBUG=False, num_images=None):
        csv = open(csv_file, 'r').read()
        datalist = list((row.split(',') for row in (csv).split('\n') if len(row) > 0))

        datalist = shuffle(datalist, random_state=10)

        if num_images is None:
            num_images = len(datalist)

        if DEBUG:
            num_images = 10
        
        split_pt = int(num_images * (self.split_ratio - 1) / self.split_ratio)
        train = datalist[0:split_pt]
        test = datalist[split_pt:num_images]

        self.train_filenames = [i[0] for i in train]
        self.train_labels = [i[1] for i in train]

        self.test_filenames = [i[0] for i in test]
        self.test_labels = [i[1] for i in test]

    def _parse_function(self, filename, label): 
        # Read images from disk
        image_decoded = tf.image.decode_jpeg(tf.io.read_file(filename))
        depth_resized = tf.image.resize(tf.image.decode_jpeg(tf.io.read_file(label)), [self.shape_depth[0], self.shape_depth[1]])

        # Format
        rgb = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        depth = tf.image.convert_image_dtype(depth_resized / 255.0, dtype=tf.float32)
        
        # Normalize the depth values (in cm)
        depth = 1000 / tf.clip_by_value(depth * 1000, 10, 1000)

        return rgb, depth

    def get_batched_dataset(self, batch_size):
        train_data = tf.data.Dataset.from_tensor_slices((self.train_filenames, self.train_labels)) \
                        .shuffle(buffer_size=len(self.train_filenames), reshuffle_each_iteration=True) \
                        .repeat() \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)

        test_data = tf.data.Dataset.from_tensor_slices((self.test_filenames, self.test_labels)) \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)
                    
        return train_data, test_data

# %% [markdown]
# # Train

# %%
import math

batch_size = 6
learning_rate = 0.0001
c_split_ratio = 5

# Max total batches: 6336 at batch_size=8
## Keep train_batch_num higher to not let model overfit
train_batch_num = 5000

def get_num_images(train_batch_num):
    num_images = int((batch_size * train_batch_num) * (c_split_ratio / (c_split_ratio-1)))
    return num_images

num_images = get_num_images(train_batch_num)
print(num_images)
test_batch_num = math.ceil((num_images - train_batch_num * batch_size) * 1.0 / batch_size)
print(test_batch_num)

if test_batch_num + train_batch_num > 6300:
    print("TF Warning")
# Out:
# 37500
# 1250

# %%
dl = DataLoader(csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', NUMBER_DATA=num_images)
train_generator, val_generator = dl.get_batched_dataset(batch_size)

# %%
os.chdir(DATA_PATH)
os.getcwd()
# Out:
# '/content/drive/MyDrive/Dense_depth'

# %%
model = DenseDepth()
model.compile(loss=depth_loss, 
              optimizer=tf.keras.optimizers.Adam(lr=learning_rate, amsgrad=True))

checkpoint_path = "/content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
                    checkpoint_path, save_weights_only=False, verbose=1,
                    save_best_only=True)

EPOCHS = 200
train_steps = 50
val_steps = 10

es_patience = EPOCHS//10
early_stop = tf.keras.callbacks.EarlyStopping(
                    patience=es_patience,
                    restore_best_weights=True)

history = model.fit(train_generator, epochs=EPOCHS, steps_per_epoch=train_steps, 
                    validation_data=val_generator, validation_steps=val_steps, 
                    #validation_split=0.2,
                    shuffle=True, 
                    callbacks=[cp_callback], 
                    verbose=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 0s 0us/step
# Epoch 1/200
# 50/50 [==============================] - 320s 4s/step - loss: 0.3799 - val_loss: 0.3714
#
# Epoch 00001: val_loss improved from inf to 0.37143, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 2/200
# 50/50 [==============================] - 96s 2s/step - loss: 0.2402 - val_loss: 0.4110
#
# Epoch 00002: val_loss did not improve from 0.37143
# Epoch 3/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.2247 - val_loss: 0.2267
#
# Epoch 00003: val_loss improved from 0.37143 to 0.22670, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 4/200
# 50/50 [==============================] - 96s 2s/step - loss: 0.2230 - val_loss: 0.1952
#
# Epoch 00004: val_loss improved from 0.22670 to 0.19520, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 5/200
# 50/50 [==============================] - 96s 2s/step - loss: 0.2130 - val_loss: 0.1816
#
# Epoch 00005: val_loss improved from 0.19520 to 0.18161, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 6/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.2131 - val_loss: 0.1856
#
# Epoch 00006: val_loss did not improve from 0.18161
# Epoch 7/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1952 - val_loss: 0.2067
#
# Epoch 00007: val_loss did not improve from 0.18161
# Epoch 8/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1883 - val_loss: 0.2014
#
# Epoch 00008: val_loss did not improve from 0.18161
# Epoch 9/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1995 - val_loss: 0.1637
#
# Epoch 00009: val_loss improved from 0.18161 to 0.16369, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 10/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1791 - val_loss: 0.1786
#
# Epoch 00010: val_loss did not improve from 0.16369
# Epoch 11/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1826 - val_loss: 0.2070
#
# Epoch 00011: val_loss did not improve from 0.16369
# Epoch 12/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1644 - val_loss: 0.2090
#
# Epoch 00012: val_loss did not improve from 0.16369
# Epoch 13/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1804 - val_loss: 0.1620
#
# Epoch 00013: val_loss improved from 0.16369 to 0.16198, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 14/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1908 - val_loss: 0.1662
#
# Epoch 00014: val_loss did not improve from 0.16198
# Epoch 15/200
# 50/50 [==============================] - 95s 2s/step - loss: 0.1754 - val_loss: 0.1571
#
# Epoch 00015: val_loss improved from 0.16198 to 0.15710, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 16/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1670 - val_loss: 0.1640
#
# Epoch 00016: val_loss did not improve from 0.15710
# Epoch 17/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1526 - val_loss: 0.1693
#
# Epoch 00017: val_loss did not improve from 0.15710
# Epoch 18/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1817 - val_loss: 0.1543
#
# Epoch 00018: val_loss improved from 0.15710 to 0.15430, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 19/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1674 - val_loss: 0.1622
#
# Epoch 00019: val_loss did not improve from 0.15430
# Epoch 20/200
# 50/50 [==============================] - 126s 3s/step - loss: 0.1641 - val_loss: 0.1564
#
# Epoch 00020: val_loss did not improve from 0.15430
# Epoch 21/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1694 - val_loss: 0.1526
#
# Epoch 00021: val_loss improved from 0.15430 to 0.15257, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 22/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1655 - val_loss: 0.1502
#
# Epoch 00022: val_loss improved from 0.15257 to 0.15022, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 23/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1353 - val_loss: 0.1623
#
# Epoch 00023: val_loss did not improve from 0.15022
# Epoch 24/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1586 - val_loss: 0.1526
#
# Epoch 00024: val_loss did not improve from 0.15022
# Epoch 25/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1664 - val_loss: 0.1523
#
# Epoch 00025: val_loss did not improve from 0.15022
# Epoch 26/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1612 - val_loss: 0.1440
#
# Epoch 00026: val_loss improved from 0.15022 to 0.14404, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 27/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1579 - val_loss: 0.1365
#
# Epoch 00027: val_loss improved from 0.14404 to 0.13648, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 28/200
# 50/50 [==============================] - 91s 2s/step - loss: 0.1610 - val_loss: 0.1531
#
# Epoch 00028: val_loss did not improve from 0.13648
# Epoch 29/200
# 50/50 [==============================] - 91s 2s/step - loss: 0.1529 - val_loss: 0.1659
#
# Epoch 00029: val_loss did not improve from 0.13648
# Epoch 30/200
# 50/50 [==============================] - 91s 2s/step - loss: 0.1509 - val_loss: 0.1546
#
# Epoch 00030: val_loss did not improve from 0.13648
# Epoch 31/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1514 - val_loss: 0.1432
#
# Epoch 00031: val_loss did not improve from 0.13648
# Epoch 32/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1570 - val_loss: 0.1373
#
# Epoch 00032: val_loss did not improve from 0.13648
# Epoch 33/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1452 - val_loss: 0.1704
#
# Epoch 00033: val_loss did not improve from 0.13648
# Epoch 34/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1598 - val_loss: 0.1759
#
# Epoch 00034: val_loss did not improve from 0.13648
# Epoch 35/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1720 - val_loss: 0.1399
#
# Epoch 00035: val_loss did not improve from 0.13648
# Epoch 36/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1667 - val_loss: 0.1373
#
# Epoch 00036: val_loss did not improve from 0.13648
# Epoch 37/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1500 - val_loss: 0.1382
#
# Epoch 00037: val_loss did not improve from 0.13648
# Epoch 38/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1394 - val_loss: 0.1371
#
# Epoch 00038: val_loss did not improve from 0.13648
# Epoch 39/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1262 - val_loss: 0.1350
#
# Epoch 00039: val_loss improved from 0.13648 to 0.13499, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 40/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1420 - val_loss: 0.1328
#
# Epoch 00040: val_loss improved from 0.13499 to 0.13281, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 41/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1520 - val_loss: 0.1301
#
# Epoch 00041: val_loss improved from 0.13281 to 0.13010, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 42/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1386 - val_loss: 0.1359
#
# Epoch 00042: val_loss did not improve from 0.13010
# Epoch 43/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1327 - val_loss: 0.1356
#
# Epoch 00043: val_loss did not improve from 0.13010
# Epoch 44/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1401 - val_loss: 0.1530
#
# Epoch 00044: val_loss did not improve from 0.13010
# Epoch 45/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1441 - val_loss: 0.1347
#
# Epoch 00045: val_loss did not improve from 0.13010
# Epoch 46/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1323 - val_loss: 0.1336
#
# Epoch 00046: val_loss did not improve from 0.13010
# Epoch 47/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1478 - val_loss: 0.1436
#
# Epoch 00047: val_loss did not improve from 0.13010
# Epoch 48/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1352 - val_loss: 0.1341
#
# Epoch 00048: val_loss did not improve from 0.13010
# Epoch 49/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1341 - val_loss: 0.1437
#
# Epoch 00049: val_loss did not improve from 0.13010
# Epoch 50/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1370 - val_loss: 0.1342
#
# Epoch 00050: val_loss did not improve from 0.13010
# Epoch 51/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1446 - val_loss: 0.1215
#
# Epoch 00051: val_loss improved from 0.13010 to 0.12147, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 52/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1301 - val_loss: 0.1374
#
# Epoch 00052: val_loss did not improve from 0.12147
# Epoch 53/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1315 - val_loss: 0.1328
#
# Epoch 00053: val_loss did not improve from 0.12147
# Epoch 54/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1364 - val_loss: 0.1244
#
# Epoch 00054: val_loss did not improve from 0.12147
# Epoch 55/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1358 - val_loss: 0.1295
#
# Epoch 00055: val_loss did not improve from 0.12147
# Epoch 56/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1356 - val_loss: 0.1282
#
# Epoch 00056: val_loss did not improve from 0.12147
# Epoch 57/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1372 - val_loss: 0.1255
#
# Epoch 00057: val_loss did not improve from 0.12147
# Epoch 58/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1294 - val_loss: 0.1306
#
# Epoch 00058: val_loss did not improve from 0.12147
# Epoch 59/200
# 50/50 [==============================] - 91s 2s/step - loss: 0.1361 - val_loss: 0.1228
#
# Epoch 00059: val_loss did not improve from 0.12147
# Epoch 60/200
# 50/50 [==============================] - 89s 2s/step - loss: 0.1278 - val_loss: 0.1258
#
# Epoch 00060: val_loss did not improve from 0.12147
# Epoch 61/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1322 - val_loss: 0.1382
#
# Epoch 00061: val_loss did not improve from 0.12147
# Epoch 62/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1360 - val_loss: 0.1368
#
# Epoch 00062: val_loss did not improve from 0.12147
# Epoch 63/200
# 50/50 [==============================] - 91s 2s/step - loss: 0.1254 - val_loss: 0.1269
#
# Epoch 00063: val_loss did not improve from 0.12147
# Epoch 64/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1325 - val_loss: 0.1266
#
# Epoch 00064: val_loss did not improve from 0.12147
# Epoch 65/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1365 - val_loss: 0.1265
#
# Epoch 00065: val_loss did not improve from 0.12147
# Epoch 66/200
# 50/50 [==============================] - 95s 2s/step - loss: 0.1316 - val_loss: 0.1175
#
# Epoch 00066: val_loss improved from 0.12147 to 0.11755, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 67/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1270 - val_loss: 0.1192
#
# Epoch 00067: val_loss did not improve from 0.11755
# Epoch 68/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1287 - val_loss: 0.1206
#
# Epoch 00068: val_loss did not improve from 0.11755
# Epoch 69/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1206 - val_loss: 0.1181
#
# Epoch 00069: val_loss did not improve from 0.11755
# Epoch 70/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1268 - val_loss: 0.1290
#
# Epoch 00070: val_loss did not improve from 0.11755
# Epoch 71/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1355 - val_loss: 0.1334
#
# Epoch 00071: val_loss did not improve from 0.11755
# Epoch 72/200
# 50/50 [==============================] - 96s 2s/step - loss: 0.1315 - val_loss: 0.1229
#
# Epoch 00072: val_loss did not improve from 0.11755
# Epoch 73/200
# 50/50 [==============================] - 95s 2s/step - loss: 0.1221 - val_loss: 0.1304
#
# Epoch 00073: val_loss did not improve from 0.11755
# Epoch 74/200
# 50/50 [==============================] - 97s 2s/step - loss: 0.1197 - val_loss: 0.1165
#
# Epoch 00074: val_loss improved from 0.11755 to 0.11646, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 75/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1177 - val_loss: 0.1177
#
# Epoch 00075: val_loss did not improve from 0.11646
# Epoch 76/200
# 50/50 [==============================] - 98s 2s/step - loss: 0.1303 - val_loss: 0.1177
#
# Epoch 00076: val_loss did not improve from 0.11646
# Epoch 77/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1275 - val_loss: 0.1148
#
# Epoch 00077: val_loss improved from 0.11646 to 0.11476, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 78/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1215 - val_loss: 0.1136
#
# Epoch 00078: val_loss improved from 0.11476 to 0.11360, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 79/200
# 50/50 [==============================] - 95s 2s/step - loss: 0.1212 - val_loss: 0.1175
#
# Epoch 00079: val_loss did not improve from 0.11360
# Epoch 80/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1207 - val_loss: 0.1275
#
# Epoch 00080: val_loss did not improve from 0.11360
# Epoch 81/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1209 - val_loss: 0.1165
#
# Epoch 00081: val_loss did not improve from 0.11360
# Epoch 82/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1174 - val_loss: 0.1144
#
# Epoch 00082: val_loss did not improve from 0.11360
# Epoch 83/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1167 - val_loss: 0.1170
#
# Epoch 00083: val_loss did not improve from 0.11360
# Epoch 84/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1194 - val_loss: 0.1152
#
# Epoch 00084: val_loss did not improve from 0.11360
# Epoch 85/200
# 50/50 [==============================] - 95s 2s/step - loss: 0.1167 - val_loss: 0.1150
#
# Epoch 00085: val_loss did not improve from 0.11360
# Epoch 86/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1227 - val_loss: 0.1209
#
# Epoch 00086: val_loss did not improve from 0.11360
# Epoch 87/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1209 - val_loss: 0.1134
#
# Epoch 00087: val_loss improved from 0.11360 to 0.11339, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 88/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1134 - val_loss: 0.1149
#
# Epoch 00088: val_loss did not improve from 0.11339
# Epoch 89/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1198 - val_loss: 0.1168
#
# Epoch 00089: val_loss did not improve from 0.11339
# Epoch 90/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1190 - val_loss: 0.1139
#
# Epoch 00090: val_loss did not improve from 0.11339
# Epoch 91/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1140 - val_loss: 0.1120
#
# Epoch 00091: val_loss improved from 0.11339 to 0.11195, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 92/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1201 - val_loss: 0.1150
#
# Epoch 00092: val_loss did not improve from 0.11195
# Epoch 93/200
# 50/50 [==============================] - 94s 2s/step - loss: 0.1145 - val_loss: 0.1389
#
# Epoch 00093: val_loss did not improve from 0.11195
# Epoch 94/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1211 - val_loss: 0.1114
#
# Epoch 00094: val_loss improved from 0.11195 to 0.11138, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 95/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1165 - val_loss: 0.1159
#
# Epoch 00095: val_loss did not improve from 0.11138
# Epoch 96/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1182 - val_loss: 0.1151
#
# Epoch 00096: val_loss did not improve from 0.11138
# Epoch 97/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1130 - val_loss: 0.1148
#
# Epoch 00097: val_loss did not improve from 0.11138
# Epoch 98/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1145 - val_loss: 0.1127
#
# Epoch 00098: val_loss did not improve from 0.11138
# Epoch 99/200
# 50/50 [==============================] - 93s 2s/step - loss: 0.1128 - val_loss: 0.1143
#
# Epoch 00099: val_loss did not improve from 0.11138
# Epoch 100/200
# 50/50 [==============================] - 92s 2s/step - loss: 0.1124 - val_loss: 0.1122
#
# Epoch 00100: val_loss did not improve from 0.11138
# Epoch 101/200
# 50/50 [==============================] - 41s 813ms/step - loss: 0.1166 - val_loss: 0.1144
#
# Epoch 00101: val_loss did not improve from 0.11138
# Epoch 102/200
# 50/50 [==============================] - 40s 805ms/step - loss: 0.1153 - val_loss: 0.1113
#
# Epoch 00102: val_loss improved from 0.11138 to 0.11131, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 103/200
# 50/50 [==============================] - 41s 811ms/step - loss: 0.1083 - val_loss: 0.1115
#
# Epoch 00103: val_loss did not improve from 0.11131
# Epoch 104/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1139 - val_loss: 0.1146
#
# Epoch 00104: val_loss did not improve from 0.11131
# Epoch 105/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1042 - val_loss: 0.1100
#
# Epoch 00105: val_loss improved from 0.11131 to 0.11003, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 106/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1217 - val_loss: 0.1087
#
# Epoch 00106: val_loss improved from 0.11003 to 0.10873, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 107/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.0991 - val_loss: 0.1088
#
# Epoch 00107: val_loss did not improve from 0.10873
# Epoch 108/200
# 50/50 [==============================] - 40s 805ms/step - loss: 0.1137 - val_loss: 0.1101
#
# Epoch 00108: val_loss did not improve from 0.10873
# Epoch 109/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1060 - val_loss: 0.1094
#
# Epoch 00109: val_loss did not improve from 0.10873
# Epoch 110/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1162 - val_loss: 0.1098
#
# Epoch 00110: val_loss did not improve from 0.10873
# Epoch 111/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1102 - val_loss: 0.1080
#
# Epoch 00111: val_loss improved from 0.10873 to 0.10798, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 112/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1070 - val_loss: 0.1122
#
# Epoch 00112: val_loss did not improve from 0.10798
# Epoch 113/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1089 - val_loss: 0.1084
#
# Epoch 00113: val_loss did not improve from 0.10798
# Epoch 114/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1141 - val_loss: 0.1069
#
# Epoch 00114: val_loss improved from 0.10798 to 0.10690, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 115/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1053 - val_loss: 0.1059
#
# Epoch 00115: val_loss improved from 0.10690 to 0.10595, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 116/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1039 - val_loss: 0.1087
#
# Epoch 00116: val_loss did not improve from 0.10595
# Epoch 117/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1117 - val_loss: 0.1055
#
# Epoch 00117: val_loss improved from 0.10595 to 0.10552, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 118/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1067 - val_loss: 0.1101
#
# Epoch 00118: val_loss did not improve from 0.10552
# Epoch 119/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1024 - val_loss: 0.1112
#
# Epoch 00119: val_loss did not improve from 0.10552
# Epoch 120/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1036 - val_loss: 0.1042
#
# Epoch 00120: val_loss improved from 0.10552 to 0.10417, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 121/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1102 - val_loss: 0.1071
#
# Epoch 00121: val_loss did not improve from 0.10417
# Epoch 122/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1049 - val_loss: 0.1101
#
# Epoch 00122: val_loss did not improve from 0.10417
# Epoch 123/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1078 - val_loss: 0.1107
#
# Epoch 00123: val_loss did not improve from 0.10417
# Epoch 124/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1001 - val_loss: 0.1080
#
# Epoch 00124: val_loss did not improve from 0.10417
# Epoch 125/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1118 - val_loss: 0.1126
#
# Epoch 00125: val_loss did not improve from 0.10417
# Epoch 126/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1099 - val_loss: 0.1108
#
# Epoch 00126: val_loss did not improve from 0.10417
# Epoch 127/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1096 - val_loss: 0.1157
#
# Epoch 00127: val_loss did not improve from 0.10417
# Epoch 128/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1087 - val_loss: 0.1066
#
# Epoch 00128: val_loss did not improve from 0.10417
# Epoch 129/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.0995 - val_loss: 0.1034
#
# Epoch 00129: val_loss improved from 0.10417 to 0.10336, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 130/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1039 - val_loss: 0.1136
#
# Epoch 00130: val_loss did not improve from 0.10336
# Epoch 131/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1091 - val_loss: 0.1042
#
# Epoch 00131: val_loss did not improve from 0.10336
# Epoch 132/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.0981 - val_loss: 0.1049
#
# Epoch 00132: val_loss did not improve from 0.10336
# Epoch 133/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1023 - val_loss: 0.1027
#
# Epoch 00133: val_loss improved from 0.10336 to 0.10271, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 134/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1088 - val_loss: 0.1068
#
# Epoch 00134: val_loss did not improve from 0.10271
# Epoch 135/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1090 - val_loss: 0.1248
#
# Epoch 00135: val_loss did not improve from 0.10271
# Epoch 136/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1131 - val_loss: 0.1091
#
# Epoch 00136: val_loss did not improve from 0.10271
# Epoch 137/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1102 - val_loss: 0.1068
#
# Epoch 00137: val_loss did not improve from 0.10271
# Epoch 138/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1076 - val_loss: 0.1058
#
# Epoch 00138: val_loss did not improve from 0.10271
# Epoch 139/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1063 - val_loss: 0.1176
#
# Epoch 00139: val_loss did not improve from 0.10271
# Epoch 140/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1019 - val_loss: 0.1101
#
# Epoch 00140: val_loss did not improve from 0.10271
# Epoch 141/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1058 - val_loss: 0.1154
#
# Epoch 00141: val_loss did not improve from 0.10271
# Epoch 142/200
# 50/50 [==============================] - 40s 811ms/step - loss: 0.1053 - val_loss: 0.1084
#
# Epoch 00142: val_loss did not improve from 0.10271
# Epoch 143/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1121 - val_loss: 0.1052
#
# Epoch 00143: val_loss did not improve from 0.10271
# Epoch 144/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1067 - val_loss: 0.1055
#
# Epoch 00144: val_loss did not improve from 0.10271
# Epoch 145/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1040 - val_loss: 0.1119
#
# Epoch 00145: val_loss did not improve from 0.10271
# Epoch 146/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1077 - val_loss: 0.1048
#
# Epoch 00146: val_loss did not improve from 0.10271
# Epoch 147/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1070 - val_loss: 0.1206
#
# Epoch 00147: val_loss did not improve from 0.10271
# Epoch 148/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1073 - val_loss: 0.1081
#
# Epoch 00148: val_loss did not improve from 0.10271
# Epoch 149/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1051 - val_loss: 0.1057
#
# Epoch 00149: val_loss did not improve from 0.10271
# Epoch 150/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1049 - val_loss: 0.1049
#
# Epoch 00150: val_loss did not improve from 0.10271
# Epoch 151/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1032 - val_loss: 0.1081
#
# Epoch 00151: val_loss did not improve from 0.10271
# Epoch 152/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1041 - val_loss: 0.1042
#
# Epoch 00152: val_loss did not improve from 0.10271
# Epoch 153/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1067 - val_loss: 0.1020
#
# Epoch 00153: val_loss improved from 0.10271 to 0.10203, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 154/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1026 - val_loss: 0.1020
#
# Epoch 00154: val_loss improved from 0.10203 to 0.10195, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 155/200
# 50/50 [==============================] - 41s 810ms/step - loss: 0.1011 - val_loss: 0.1076
#
# Epoch 00155: val_loss did not improve from 0.10195
# Epoch 156/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1038 - val_loss: 0.1029
#
# Epoch 00156: val_loss did not improve from 0.10195
# Epoch 157/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1030 - val_loss: 0.1013
#
# Epoch 00157: val_loss improved from 0.10195 to 0.10130, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 158/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1009 - val_loss: 0.1046
#
# Epoch 00158: val_loss did not improve from 0.10130
# Epoch 159/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1125 - val_loss: 0.1048
#
# Epoch 00159: val_loss did not improve from 0.10130
# Epoch 160/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.0964 - val_loss: 0.1047
#
# Epoch 00160: val_loss did not improve from 0.10130
# Epoch 161/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1043 - val_loss: 0.1007
#
# Epoch 00161: val_loss improved from 0.10130 to 0.10068, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 162/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1021 - val_loss: 0.1024
#
# Epoch 00162: val_loss did not improve from 0.10068
# Epoch 163/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1006 - val_loss: 0.1039
#
# Epoch 00163: val_loss did not improve from 0.10068
# Epoch 164/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1005 - val_loss: 0.1046
#
# Epoch 00164: val_loss did not improve from 0.10068
# Epoch 165/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1058 - val_loss: 0.1077
#
# Epoch 00165: val_loss did not improve from 0.10068
# Epoch 166/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.0981 - val_loss: 0.0999
#
# Epoch 00166: val_loss improved from 0.10068 to 0.09990, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 167/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.1028 - val_loss: 0.1025
#
# Epoch 00167: val_loss did not improve from 0.09990
# Epoch 168/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.0954 - val_loss: 0.1031
#
# Epoch 00168: val_loss did not improve from 0.09990
# Epoch 169/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1026 - val_loss: 0.1059
#
# Epoch 00169: val_loss did not improve from 0.09990
# Epoch 170/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1059 - val_loss: 0.0990
#
# Epoch 00170: val_loss improved from 0.09990 to 0.09903, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 171/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1015 - val_loss: 0.1012
#
# Epoch 00171: val_loss did not improve from 0.09903
# Epoch 172/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.0995 - val_loss: 0.0997
#
# Epoch 00172: val_loss did not improve from 0.09903
# Epoch 173/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1040 - val_loss: 0.0992
#
# Epoch 00173: val_loss did not improve from 0.09903
# Epoch 174/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.0983 - val_loss: 0.0996
#
# Epoch 00174: val_loss did not improve from 0.09903
# Epoch 175/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1001 - val_loss: 0.1124
#
# Epoch 00175: val_loss did not improve from 0.09903
# Epoch 176/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1000 - val_loss: 0.1017
#
# Epoch 00176: val_loss did not improve from 0.09903
# Epoch 177/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1031 - val_loss: 0.1023
#
# Epoch 00177: val_loss did not improve from 0.09903
# Epoch 178/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1055 - val_loss: 0.0985
#
# Epoch 00178: val_loss improved from 0.09903 to 0.09850, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 179/200
# 50/50 [==============================] - 41s 810ms/step - loss: 0.1060 - val_loss: 0.1019
#
# Epoch 00179: val_loss did not improve from 0.09850
# Epoch 180/200
# 50/50 [==============================] - 40s 805ms/step - loss: 0.1020 - val_loss: 0.1009
#
# Epoch 00180: val_loss did not improve from 0.09850
# Epoch 181/200
# 50/50 [==============================] - 40s 806ms/step - loss: 0.0983 - val_loss: 0.1000
#
# Epoch 00181: val_loss did not improve from 0.09850
# Epoch 182/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0946 - val_loss: 0.1028
#
# Epoch 00182: val_loss did not improve from 0.09850
# Epoch 183/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1017 - val_loss: 0.0972
#
# Epoch 00183: val_loss improved from 0.09850 to 0.09717, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 184/200
# 50/50 [==============================] - 41s 810ms/step - loss: 0.1017 - val_loss: 0.1005
#
# Epoch 00184: val_loss did not improve from 0.09717
# Epoch 185/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.1022 - val_loss: 0.0989
#
# Epoch 00185: val_loss did not improve from 0.09717
# Epoch 186/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0977 - val_loss: 0.0978
#
# Epoch 00186: val_loss did not improve from 0.09717
# Epoch 187/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.1041 - val_loss: 0.0989
#
# Epoch 00187: val_loss did not improve from 0.09717
# Epoch 188/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1011 - val_loss: 0.1078
#
# Epoch 00188: val_loss did not improve from 0.09717
# Epoch 189/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0977 - val_loss: 0.0994
#
# Epoch 00189: val_loss did not improve from 0.09717
# Epoch 190/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1011 - val_loss: 0.0986
#
# Epoch 00190: val_loss did not improve from 0.09717
# Epoch 191/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.0996 - val_loss: 0.0963
#
# Epoch 00191: val_loss improved from 0.09717 to 0.09630, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 192/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0942 - val_loss: 0.1046
#
# Epoch 00192: val_loss did not improve from 0.09630
# Epoch 193/200
# 50/50 [==============================] - 40s 810ms/step - loss: 0.0989 - val_loss: 0.0972
#
# Epoch 00193: val_loss did not improve from 0.09630
# Epoch 194/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.0947 - val_loss: 0.1009
#
# Epoch 00194: val_loss did not improve from 0.09630
# Epoch 195/200
# 50/50 [==============================] - 40s 807ms/step - loss: 0.1014 - val_loss: 0.0956
#
# Epoch 00195: val_loss improved from 0.09630 to 0.09559, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 196/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.0942 - val_loss: 0.0976
#
# Epoch 00196: val_loss did not improve from 0.09559
# Epoch 197/200
# 50/50 [==============================] - 40s 809ms/step - loss: 0.1029 - val_loss: 0.0965
#
# Epoch 00197: val_loss did not improve from 0.09559
# Epoch 198/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0934 - val_loss: 0.0966
#
# Epoch 00198: val_loss did not improve from 0.09559
# Epoch 199/200
# 50/50 [==============================] - 40s 808ms/step - loss: 0.0955 - val_loss: 0.0953
#
# Epoch 00199: val_loss improved from 0.09559 to 0.09531, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 200/200
# 50/50 [==============================] - 41s 810ms/step - loss: 0.1040 - val_loss: 0.1011
#
# Epoch 00200: val_loss did not improve from 0.09531

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 8))

plt.plot(epochs_range, loss, label='Training loss')
plt.plot(epochs_range, val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Loss | Batch size = ' + str(batch_size) + ', steps_per_epoch = ' + str(train_steps) + ', validation_steps = ' + str(val_steps))
plt.xlabel('epochs')
os.chdir(SAVE_PATH)
plt.savefig('loss.png')

# %% [markdown]
# # Test Helper functions

# %% [markdown]
# ## Utils

# %%
import cv2
import numpy as np

def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %% [markdown]
# # Test

# %%
os.chdir(SAVE_PATH)
print('Loading model...')
model = DenseDepth()
checkpoint_path = "Training/DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# Model weights loaded.

# %%
count = 3

os.chdir(SAVE_PATH)
path_pre = DATA_PATH + 'data/nyu2_test/'
files = [f for f in os.listdir(path_pre) if f.split('_')[1] == 'colors.png']
(fig, axes) = plt.subplots(nrows=count, ncols=3, figsize=(15,15))
i = 0
for f in files:
    file_id = f.split('_')[0]
    depth_file = file_id + '_depth.png'
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('RGB')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('Predicted')

    img = cv2.imread(path_pre + depth_file, cv2.IMREAD_ANYDEPTH)
    axes[i][1].imshow(img, cmap='plasma')
    axes[i][1].set_title('Ground Truth')
    
    if i == count-1:
        break
    else:
        i += 1

plt.savefig('result.png')

# %% [markdown]
# # Evaluation

# %%
from evaluate import load_test_data, evaluate

rgb, depth, crop = load_test_data()
evaluate(model, rgb, depth, crop)
# Out:
# Loading test data...Test data loaded.
#
#         a1,         a2,         a3,        rel,        rms,     log_10
#     0.8121,     0.9658,     0.9933,     0.1365,     0.5053,     0.0594

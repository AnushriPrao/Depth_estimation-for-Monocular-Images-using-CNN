# %% [markdown]
# # Download Train and Test data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Dense_depth
# Out:
# /content/drive/My Drive/Dense_depth

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /content/drive/My Drive/Dense_depth

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_data.zip
# !unzip nyu_data.zip

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_test.zip

# %% [markdown]
# # Set Paths

# %%
import os
DATA_PATH = '/content/drive/MyDrive/Dense_depth/'
SAVE_PATH = '/content/drive/MyDrive/Dense_depth'
#os.chdir(SAVE_PATH)
os.getcwd()
# Out:
# '/content/drive/My Drive/Dense_depth'

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Loss function

# %%
def depth_loss(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    # Point-wise depth
    l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    # Edges
    dy_true, dx_true = tf.image.image_gradients(y_true)
    dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    l_edges = K.mean(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)

    # Structural similarity (SSIM) index
    l_ssim = K.clip((1 - tf.image.ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    return (w1 * l_ssim) + (w2 * K.mean(l_edges)) + (w3 * K.mean(l_depth))

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear')
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3) ,include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %% [markdown]
# ## Decode Block

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %% [markdown]
# ## Combining Encoder and Decoder

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

# %% [markdown]
# # Data Loader

# %%
import tensorflow as tf

from sklearn.utils import shuffle

class DataLoader():
    def __init__(self, csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', DEBUG=False, NUMBER_DATA=None, split_ratio=5):
        self.shape_rgb = (480, 640, 3)
        self.shape_depth = (240, 320, 1)
        self.split_ratio = split_ratio
        self.read_data(csv_file, DEBUG=DEBUG, num_images=NUMBER_DATA)

    def nyu_resize(self, img, resolution=480, padding=6):
        from skimage.transform import resize
        return resize(img, (resolution, int(resolution*4/3)), preserve_range=True, mode='reflect', anti_aliasing=True )

    def read_data(self, csv_file, DEBUG=False, num_images=None):
        csv = open(csv_file, 'r').read()
        datalist = list((row.split(',') for row in (csv).split('\n') if len(row) > 0))

        datalist = shuffle(datalist, random_state=10)

        if num_images is None:
            num_images = len(datalist)

        if DEBUG:
            num_images = 10
        
        split_pt = int(num_images * (self.split_ratio - 1) / self.split_ratio)
        train = datalist[0:split_pt]
        test = datalist[split_pt:num_images]

        self.train_filenames = [i[0] for i in train]
        self.train_labels = [i[1] for i in train]

        self.test_filenames = [i[0] for i in test]
        self.test_labels = [i[1] for i in test]

    def _parse_function(self, filename, label): 
        # Read images from disk
        image_decoded = tf.image.decode_jpeg(tf.io.read_file(filename))
        depth_resized = tf.image.resize(tf.image.decode_jpeg(tf.io.read_file(label)), [self.shape_depth[0], self.shape_depth[1]])

        # Format
        rgb = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        depth = tf.image.convert_image_dtype(depth_resized / 255.0, dtype=tf.float32)
        
        # Normalize the depth values (in cm)
        depth = 1000 / tf.clip_by_value(depth * 1000, 10, 1000)

        return rgb, depth

    def get_batched_dataset(self, batch_size):
        train_data = tf.data.Dataset.from_tensor_slices((self.train_filenames, self.train_labels)) \
                        .shuffle(buffer_size=len(self.train_filenames), reshuffle_each_iteration=True) \
                        .repeat() \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)

        test_data = tf.data.Dataset.from_tensor_slices((self.test_filenames, self.test_labels)) \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)
                    
        return train_data, test_data

# %% [markdown]
# # Train

# %%
import math

batch_size = 6
learning_rate = 0.0001
c_split_ratio = 5

# Max total batches: 6336 at batch_size=8
## Keep train_batch_num higher to not let model overfit
train_batch_num = 5000

def get_num_images(train_batch_num):
    num_images = int((batch_size * train_batch_num) * (c_split_ratio / (c_split_ratio-1)))
    return num_images

num_images = get_num_images(train_batch_num)
print(num_images)
test_batch_num = math.ceil((num_images - train_batch_num * batch_size) * 1.0 / batch_size)
print(test_batch_num)

if test_batch_num + train_batch_num > 6300:
    print("TF Warning")
# Out:
# 37500
# 1250

# %%
dl = DataLoader(csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', NUMBER_DATA=num_images)
train_generator, val_generator = dl.get_batched_dataset(batch_size)

# %%
os.chdir(DATA_PATH)
os.getcwd()
# Out:
# '/content/drive/MyDrive/Dense_depth'

# %%
model = DenseDepth()
model.compile(loss=depth_loss, 
              optimizer=tf.keras.optimizers.Adam(lr=learning_rate, amsgrad=True))

checkpoint_path = "/content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
                    checkpoint_path, save_weights_only=False, verbose=1,
                    save_best_only=True)

EPOCHS = 100
train_steps = 50
val_steps = 10

es_patience = EPOCHS//10
early_stop = tf.keras.callbacks.EarlyStopping(
                    patience=es_patience,
                    restore_best_weights=True)

history = model.fit(train_generator, epochs=EPOCHS, steps_per_epoch=train_steps, 
                    validation_data=val_generator, validation_steps=val_steps, 
                    #validation_split=0.2,
                    shuffle=True, 
                    callbacks=[cp_callback], 
                    verbose=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# Epoch 1/100
# 50/50 [==============================] - 374s 5s/step - loss: 0.4464 - val_loss: 0.3611
#
# Epoch 00001: val_loss improved from inf to 0.36113, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 2/100
# 50/50 [==============================] - 124s 3s/step - loss: 0.2396 - val_loss: 0.3349
#
# Epoch 00002: val_loss improved from 0.36113 to 0.33489, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 3/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.2256 - val_loss: 0.2962
#
# Epoch 00003: val_loss improved from 0.33489 to 0.29615, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 4/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.2055 - val_loss: 0.2522
#
# Epoch 00004: val_loss improved from 0.29615 to 0.25217, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 5/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.2133 - val_loss: 0.2089
#
# Epoch 00005: val_loss improved from 0.25217 to 0.20888, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 6/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.2021 - val_loss: 0.1878
#
# Epoch 00006: val_loss improved from 0.20888 to 0.18782, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 7/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.2078 - val_loss: 0.1679
#
# Epoch 00007: val_loss improved from 0.18782 to 0.16791, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 8/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1852 - val_loss: 0.1692
#
# Epoch 00008: val_loss did not improve from 0.16791
# Epoch 9/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1825 - val_loss: 0.1693
#
# Epoch 00009: val_loss did not improve from 0.16791
# Epoch 10/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1909 - val_loss: 0.1676
#
# Epoch 00010: val_loss improved from 0.16791 to 0.16758, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 11/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1843 - val_loss: 0.1681
#
# Epoch 00011: val_loss did not improve from 0.16758
# Epoch 12/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1959 - val_loss: 0.2017
#
# Epoch 00012: val_loss did not improve from 0.16758
# Epoch 13/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1918 - val_loss: 0.1619
#
# Epoch 00013: val_loss improved from 0.16758 to 0.16185, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 14/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1726 - val_loss: 0.1658
#
# Epoch 00014: val_loss did not improve from 0.16185
# Epoch 15/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1694 - val_loss: 0.1660
#
# Epoch 00015: val_loss did not improve from 0.16185
# Epoch 16/100
# 50/50 [==============================] - 118s 2s/step - loss: 0.1903 - val_loss: 0.1530
#
# Epoch 00016: val_loss improved from 0.16185 to 0.15303, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 17/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1777 - val_loss: 0.1607
#
# Epoch 00017: val_loss did not improve from 0.15303
# Epoch 18/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1806 - val_loss: 0.1504
#
# Epoch 00018: val_loss improved from 0.15303 to 0.15036, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 19/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1663 - val_loss: 0.1675
#
# Epoch 00019: val_loss did not improve from 0.15036
# Epoch 20/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1693 - val_loss: 0.1716
#
# Epoch 00020: val_loss did not improve from 0.15036
# Epoch 21/100
# 50/50 [==============================] - 127s 3s/step - loss: 0.1668 - val_loss: 0.1479
#
# Epoch 00021: val_loss improved from 0.15036 to 0.14787, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 22/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1521 - val_loss: 0.1568
#
# Epoch 00022: val_loss did not improve from 0.14787
# Epoch 23/100
# 50/50 [==============================] - 137s 3s/step - loss: 0.1637 - val_loss: 0.1598
#
# Epoch 00023: val_loss did not improve from 0.14787
# Epoch 24/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.1631 - val_loss: 0.1477
#
# Epoch 00024: val_loss improved from 0.14787 to 0.14771, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 25/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1541 - val_loss: 0.1616
#
# Epoch 00025: val_loss did not improve from 0.14771
# Epoch 26/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1717 - val_loss: 0.1443
#
# Epoch 00026: val_loss improved from 0.14771 to 0.14427, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 27/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.1513 - val_loss: 0.1501
#
# Epoch 00027: val_loss did not improve from 0.14427
# Epoch 28/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1559 - val_loss: 0.1623
#
# Epoch 00028: val_loss did not improve from 0.14427
# Epoch 29/100
# 50/50 [==============================] - 123s 3s/step - loss: 0.1443 - val_loss: 0.1506
#
# Epoch 00029: val_loss did not improve from 0.14427
# Epoch 30/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1613 - val_loss: 0.1407
#
# Epoch 00030: val_loss improved from 0.14427 to 0.14070, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 31/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1488 - val_loss: 0.1365
#
# Epoch 00031: val_loss improved from 0.14070 to 0.13653, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 32/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1448 - val_loss: 0.1394
#
# Epoch 00032: val_loss did not improve from 0.13653
# Epoch 33/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1561 - val_loss: 0.1373
#
# Epoch 00033: val_loss did not improve from 0.13653
# Epoch 34/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1440 - val_loss: 0.1579
#
# Epoch 00034: val_loss did not improve from 0.13653
# Epoch 35/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1434 - val_loss: 0.1402
#
# Epoch 00035: val_loss did not improve from 0.13653
# Epoch 36/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1519 - val_loss: 0.1446
#
# Epoch 00036: val_loss did not improve from 0.13653
# Epoch 37/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1330 - val_loss: 0.1568
#
# Epoch 00037: val_loss did not improve from 0.13653
# Epoch 38/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1530 - val_loss: 0.1371
#
# Epoch 00038: val_loss did not improve from 0.13653
# Epoch 39/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1351 - val_loss: 0.1375
#
# Epoch 00039: val_loss did not improve from 0.13653
# Epoch 40/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1366 - val_loss: 0.1366
#
# Epoch 00040: val_loss did not improve from 0.13653
# Epoch 41/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1397 - val_loss: 0.1315
#
# Epoch 00041: val_loss improved from 0.13653 to 0.13154, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 42/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1412 - val_loss: 0.1397
#
# Epoch 00042: val_loss did not improve from 0.13154
# Epoch 43/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1402 - val_loss: 0.1339
#
# Epoch 00043: val_loss did not improve from 0.13154
# Epoch 44/100
# 50/50 [==============================] - 128s 3s/step - loss: 0.1323 - val_loss: 0.1329
#
# Epoch 00044: val_loss did not improve from 0.13154
# Epoch 45/100
# 50/50 [==============================] - 132s 3s/step - loss: 0.1282 - val_loss: 0.1352
#
# Epoch 00045: val_loss did not improve from 0.13154
# Epoch 46/100
# 50/50 [==============================] - 124s 3s/step - loss: 0.1344 - val_loss: 0.1523
#
# Epoch 00046: val_loss did not improve from 0.13154
# Epoch 47/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.1466 - val_loss: 0.1610
#
# Epoch 00047: val_loss did not improve from 0.13154
# Epoch 48/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.1444 - val_loss: 0.1302
#
# Epoch 00048: val_loss improved from 0.13154 to 0.13016, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 49/100
# 50/50 [==============================] - 134s 3s/step - loss: 0.1267 - val_loss: 0.1357
#
# Epoch 00049: val_loss did not improve from 0.13016
# Epoch 50/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1389 - val_loss: 0.1422
#
# Epoch 00050: val_loss did not improve from 0.13016
# Epoch 51/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1350 - val_loss: 0.1347
#
# Epoch 00051: val_loss did not improve from 0.13016
# Epoch 52/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1311 - val_loss: 0.1288
#
# Epoch 00052: val_loss improved from 0.13016 to 0.12876, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 53/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1284 - val_loss: 0.1432
#
# Epoch 00053: val_loss did not improve from 0.12876
# Epoch 54/100
# 50/50 [==============================] - 125s 3s/step - loss: 0.1319 - val_loss: 0.1303
#
# Epoch 00054: val_loss did not improve from 0.12876
# Epoch 55/100
# 50/50 [==============================] - 135s 3s/step - loss: 0.1249 - val_loss: 0.1308
#
# Epoch 00055: val_loss did not improve from 0.12876
# Epoch 56/100
# 50/50 [==============================] - 127s 3s/step - loss: 0.1253 - val_loss: 0.1313
#
# Epoch 00056: val_loss did not improve from 0.12876
# Epoch 57/100
# 50/50 [==============================] - 128s 3s/step - loss: 0.1335 - val_loss: 0.1270
#
# Epoch 00057: val_loss improved from 0.12876 to 0.12703, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 58/100
# 50/50 [==============================] - 118s 2s/step - loss: 0.1310 - val_loss: 0.1363
#
# Epoch 00058: val_loss did not improve from 0.12703
# Epoch 59/100
# 50/50 [==============================] - 153s 3s/step - loss: 0.1298 - val_loss: 0.1260
#
# Epoch 00059: val_loss improved from 0.12703 to 0.12600, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 60/100
# 50/50 [==============================] - 144s 3s/step - loss: 0.1285 - val_loss: 0.1376
#
# Epoch 00060: val_loss did not improve from 0.12600
# Epoch 61/100
# 50/50 [==============================] - 126s 3s/step - loss: 0.1316 - val_loss: 0.1281
#
# Epoch 00061: val_loss did not improve from 0.12600
# Epoch 62/100
# 50/50 [==============================] - 149s 3s/step - loss: 0.1156 - val_loss: 0.1367
#
# Epoch 00062: val_loss did not improve from 0.12600
# Epoch 63/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1362 - val_loss: 0.1224
#
# Epoch 00063: val_loss improved from 0.12600 to 0.12238, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 64/100
# 50/50 [==============================] - 131s 3s/step - loss: 0.1216 - val_loss: 0.1207
#
# Epoch 00064: val_loss improved from 0.12238 to 0.12074, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 65/100
# 50/50 [==============================] - 127s 3s/step - loss: 0.1194 - val_loss: 0.1230
#
# Epoch 00065: val_loss did not improve from 0.12074
# Epoch 66/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.1289 - val_loss: 0.1296
#
# Epoch 00066: val_loss did not improve from 0.12074
# Epoch 67/100
# 50/50 [==============================] - 131s 3s/step - loss: 0.1306 - val_loss: 0.1265
#
# Epoch 00067: val_loss did not improve from 0.12074
# Epoch 68/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1311 - val_loss: 0.1233
#
# Epoch 00068: val_loss did not improve from 0.12074
# Epoch 69/100
# 50/50 [==============================] - 129s 3s/step - loss: 0.1265 - val_loss: 0.1305
#
# Epoch 00069: val_loss did not improve from 0.12074
# Epoch 70/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1343 - val_loss: 0.1381
#
# Epoch 00070: val_loss did not improve from 0.12074
# Epoch 71/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1205 - val_loss: 0.1224
#
# Epoch 00071: val_loss did not improve from 0.12074
# Epoch 72/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1216 - val_loss: 0.1230
#
# Epoch 00072: val_loss did not improve from 0.12074
# Epoch 73/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1198 - val_loss: 0.1286
#
# Epoch 00073: val_loss did not improve from 0.12074
# Epoch 74/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1241 - val_loss: 0.1308
#
# Epoch 00074: val_loss did not improve from 0.12074
# Epoch 75/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1251 - val_loss: 0.1202
#
# Epoch 00075: val_loss improved from 0.12074 to 0.12025, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 76/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1206 - val_loss: 0.1247
#
# Epoch 00076: val_loss did not improve from 0.12025
# Epoch 77/100
# 50/50 [==============================] - 117s 2s/step - loss: 0.1244 - val_loss: 0.1212
#
# Epoch 00077: val_loss did not improve from 0.12025
# Epoch 78/100
# 50/50 [==============================] - 118s 2s/step - loss: 0.1198 - val_loss: 0.1198
#
# Epoch 00078: val_loss improved from 0.12025 to 0.11981, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 79/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1210 - val_loss: 0.1234
#
# Epoch 00079: val_loss did not improve from 0.11981
# Epoch 80/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1393 - val_loss: 0.1168
#
# Epoch 00080: val_loss improved from 0.11981 to 0.11681, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 81/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1167 - val_loss: 0.1193
#
# Epoch 00081: val_loss did not improve from 0.11681
# Epoch 82/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1122 - val_loss: 0.1164
#
# Epoch 00082: val_loss improved from 0.11681 to 0.11644, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 83/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1158 - val_loss: 0.1194
#
# Epoch 00083: val_loss did not improve from 0.11644
# Epoch 84/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1287 - val_loss: 0.1188
#
# Epoch 00084: val_loss did not improve from 0.11644
# Epoch 85/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1176 - val_loss: 0.1190
#
# Epoch 00085: val_loss did not improve from 0.11644
# Epoch 86/100
# 50/50 [==============================] - 117s 2s/step - loss: 0.1194 - val_loss: 0.1185
#
# Epoch 00086: val_loss did not improve from 0.11644
# Epoch 87/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1203 - val_loss: 0.1143
#
# Epoch 00087: val_loss improved from 0.11644 to 0.11427, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 88/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1163 - val_loss: 0.1148
#
# Epoch 00088: val_loss did not improve from 0.11427
# Epoch 89/100
# 50/50 [==============================] - 117s 2s/step - loss: 0.1280 - val_loss: 0.1199
#
# Epoch 00089: val_loss did not improve from 0.11427
# Epoch 90/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1189 - val_loss: 0.1182
#
# Epoch 00090: val_loss did not improve from 0.11427
# Epoch 91/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1170 - val_loss: 0.1147
#
# Epoch 00091: val_loss did not improve from 0.11427
# Epoch 92/100
# 50/50 [==============================] - 126s 3s/step - loss: 0.1206 - val_loss: 0.1145
#
# Epoch 00092: val_loss did not improve from 0.11427
# Epoch 93/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1155 - val_loss: 0.1122
#
# Epoch 00093: val_loss improved from 0.11427 to 0.11216, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 94/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1148 - val_loss: 0.1126
#
# Epoch 00094: val_loss did not improve from 0.11216
# Epoch 95/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1237 - val_loss: 0.1229
#
# Epoch 00095: val_loss did not improve from 0.11216
# Epoch 96/100
# 50/50 [==============================] - 123s 2s/step - loss: 0.1270 - val_loss: 0.1150
#
# Epoch 00096: val_loss did not improve from 0.11216
# Epoch 97/100
# 50/50 [==============================] - 121s 2s/step - loss: 0.1167 - val_loss: 0.1172
#
# Epoch 00097: val_loss did not improve from 0.11216
# Epoch 98/100
# 50/50 [==============================] - 122s 2s/step - loss: 0.1192 - val_loss: 0.1170
#
# Epoch 00098: val_loss did not improve from 0.11216
# Epoch 99/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.1151 - val_loss: 0.1195
#
# Epoch 00099: val_loss did not improve from 0.11216
# Epoch 100/100
# 50/50 [==============================] - 119s 2s/step - loss: 0.1130 - val_loss: 0.1132
#
# Epoch 00100: val_loss did not improve from 0.11216

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 8))

plt.plot(epochs_range, loss, label='Training loss')
plt.plot(epochs_range, val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Loss | Batch size = ' + str(batch_size) + ', steps_per_epoch = ' + str(train_steps) + ', validation_steps = ' + str(val_steps))
plt.xlabel('epochs')
os.chdir(SAVE_PATH)
plt.savefig('loss.png')

# %% [markdown]
# # Test Helper functions

# %% [markdown]
# ## Utils

# %%
import cv2
import numpy as np

def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %% [markdown]
# # Test

# %%
os.chdir(SAVE_PATH)
print('Loading model...')
model = DenseDepth()
checkpoint_path = "Training/DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# Model weights loaded.

# %%
count = 3

os.chdir(SAVE_PATH)
path_pre = DATA_PATH + 'data/nyu2_test/'
files = [f for f in os.listdir(path_pre) if f.split('_')[1] == 'colors.png']
(fig, axes) = plt.subplots(nrows=count, ncols=3, figsize=(15,15))
i = 0
for f in files:
    file_id = f.split('_')[0]
    depth_file = file_id + '_depth.png'
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('RGB')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('Predicted')

    img = cv2.imread(path_pre + depth_file, cv2.IMREAD_ANYDEPTH)
    axes[i][1].imshow(img, cmap='plasma')
    axes[i][1].set_title('Ground Truth')
    
    if i == count-1:
        break
    else:
        i += 1

plt.savefig('result.png')

# %% [markdown]
# # Evaluation

# %%
from evaluate import load_test_data, evaluate

rgb, depth, crop = load_test_data()
evaluate(model, rgb, depth, crop)
# Out:
# Loading test data...Test data loaded.
#
#         a1,         a2,         a3,        rel,        rms,     log_10
#     0.8000,     0.9622,     0.9926,     0.1431,     0.5229,     0.0620

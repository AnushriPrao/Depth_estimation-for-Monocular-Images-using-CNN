# %% [markdown]
# # Download Train and Test data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/Dense_depth
# Out:
# /content/drive/My Drive/Dense_depth

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /content/drive/My Drive/Dense_depth

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_data.zip
# !unzip nyu_data.zip

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_test.zip

# %% [markdown]
# # Set Paths

# %%
import os
DATA_PATH = '/content/drive/MyDrive/Dense_depth/'
SAVE_PATH = '/content/drive/MyDrive/Dense_depth'
#os.chdir(SAVE_PATH)
os.getcwd()
# Out:
# '/content/drive/My Drive/Dense_depth'

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Loss function

# %%
def depth_loss(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    # Point-wise depth
    l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    # Edges
    dy_true, dx_true = tf.image.image_gradients(y_true)
    dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    l_edges = K.mean(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)

    # Structural similarity (SSIM) index
    l_ssim = K.clip((1 - tf.image.ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    return (w1 * l_ssim) + (w2 * K.mean(l_edges)) + (w3 * K.mean(l_depth))

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear')
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3) ,include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %% [markdown]
# ## Decode Block

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %% [markdown]
# ## Combining Encoder and Decoder

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

# %% [markdown]
# # Data Loader

# %%
import tensorflow as tf

from sklearn.utils import shuffle

class DataLoader():
    def __init__(self, csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', DEBUG=False, NUMBER_DATA=None, split_ratio=5):
        self.shape_rgb = (480, 640, 3)
        self.shape_depth = (240, 320, 1)
        self.split_ratio = split_ratio
        self.read_data(csv_file, DEBUG=DEBUG, num_images=NUMBER_DATA)

    def nyu_resize(self, img, resolution=480, padding=6):
        from skimage.transform import resize
        return resize(img, (resolution, int(resolution*4/3)), preserve_range=True, mode='reflect', anti_aliasing=True )

    def read_data(self, csv_file, DEBUG=False, num_images=None):
        csv = open(csv_file, 'r').read()
        datalist = list((row.split(',') for row in (csv).split('\n') if len(row) > 0))

        datalist = shuffle(datalist, random_state=10)

        if num_images is None:
            num_images = len(datalist)

        if DEBUG:
            num_images = 10
        
        split_pt = int(num_images * (self.split_ratio - 1) / self.split_ratio)
        train = datalist[0:split_pt]
        test = datalist[split_pt:num_images]

        self.train_filenames = [i[0] for i in train]
        self.train_labels = [i[1] for i in train]

        self.test_filenames = [i[0] for i in test]
        self.test_labels = [i[1] for i in test]

    def _parse_function(self, filename, label): 
        # Read images from disk
        image_decoded = tf.image.decode_jpeg(tf.io.read_file(filename))
        depth_resized = tf.image.resize(tf.image.decode_jpeg(tf.io.read_file(label)), [self.shape_depth[0], self.shape_depth[1]])

        # Format
        rgb = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        depth = tf.image.convert_image_dtype(depth_resized / 255.0, dtype=tf.float32)
        
        # Normalize the depth values (in cm)
        depth = 1000 / tf.clip_by_value(depth * 1000, 10, 1000)

        return rgb, depth

    def get_batched_dataset(self, batch_size):
        train_data = tf.data.Dataset.from_tensor_slices((self.train_filenames, self.train_labels)) \
                        .shuffle(buffer_size=len(self.train_filenames), reshuffle_each_iteration=True) \
                        .repeat() \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)

        test_data = tf.data.Dataset.from_tensor_slices((self.test_filenames, self.test_labels)) \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)
                    
        return train_data, test_data

# %% [markdown]
# # Train

# %%
import math

batch_size = 6
learning_rate = 0.0001
c_split_ratio = 5

# Max total batches: 6336 at batch_size=8
## Keep train_batch_num higher to not let model overfit
train_batch_num = 5000

def get_num_images(train_batch_num):
    num_images = int((batch_size * train_batch_num) * (c_split_ratio / (c_split_ratio-1)))
    return num_images

num_images = get_num_images(train_batch_num)
print(num_images)
test_batch_num = math.ceil((num_images - train_batch_num * batch_size) * 1.0 / batch_size)
print(test_batch_num)

if test_batch_num + train_batch_num > 6300:
    print("TF Warning")
# Out:
# 37500
# 1250

# %%
dl = DataLoader(csv_file='/content/drive/MyDrive/Dense_depth/data/nyu2_train.csv', NUMBER_DATA=num_images)
train_generator, val_generator = dl.get_batched_dataset(batch_size)

# %%
os.chdir(DATA_PATH)
os.getcwd()
# Out:
# '/content/drive/MyDrive/Dense_depth'

# %%
model = DenseDepth()
model.compile(loss=depth_loss, 
              optimizer=tf.keras.optimizers.Adam(lr=learning_rate, amsgrad=True))

checkpoint_path = "/content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
                    checkpoint_path, save_weights_only=False, verbose=1,
                    save_best_only=True)

EPOCHS = 150
train_steps = 50
val_steps = 10

es_patience = EPOCHS//10
early_stop = tf.keras.callbacks.EarlyStopping(
                    patience=es_patience,
                    restore_best_weights=True)

history = model.fit(train_generator, epochs=EPOCHS, steps_per_epoch=train_steps, 
                    validation_data=val_generator, validation_steps=val_steps, 
                    #validation_split=0.2,
                    shuffle=True, 
                    callbacks=[cp_callback], 
                    verbose=1)
# Out:
# Epoch 1/150
# 50/50 [==============================] - 50s 466ms/step - loss: 0.3701 - val_loss: 0.2865
#
# Epoch 00001: val_loss improved from inf to 0.28653, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 2/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.2252 - val_loss: 0.2647
#
# Epoch 00002: val_loss improved from 0.28653 to 0.26467, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 3/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.2260 - val_loss: 0.2330
#
# Epoch 00003: val_loss improved from 0.26467 to 0.23296, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 4/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.2307 - val_loss: 0.2052
#
# Epoch 00004: val_loss improved from 0.23296 to 0.20515, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 5/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.2120 - val_loss: 0.1841
#
# Epoch 00005: val_loss improved from 0.20515 to 0.18408, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 6/150
# 50/50 [==============================] - 21s 414ms/step - loss: 0.1809 - val_loss: 0.1854
#
# Epoch 00006: val_loss did not improve from 0.18408
# Epoch 7/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1919 - val_loss: 0.1925
#
# Epoch 00007: val_loss did not improve from 0.18408
# Epoch 8/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1919 - val_loss: 0.1661
#
# Epoch 00008: val_loss improved from 0.18408 to 0.16615, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 9/150
# 50/50 [==============================] - 21s 416ms/step - loss: 0.1839 - val_loss: 0.1792
#
# Epoch 00009: val_loss did not improve from 0.16615
# Epoch 10/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1926 - val_loss: 0.1682
#
# Epoch 00010: val_loss did not improve from 0.16615
# Epoch 11/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1825 - val_loss: 0.1611
#
# Epoch 00011: val_loss improved from 0.16615 to 0.16110, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 12/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1789 - val_loss: 0.1577
#
# Epoch 00012: val_loss improved from 0.16110 to 0.15774, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 13/150
# 50/50 [==============================] - 21s 415ms/step - loss: 0.1924 - val_loss: 0.1940
#
# Epoch 00013: val_loss did not improve from 0.15774
# Epoch 14/150
# 50/50 [==============================] - 20s 411ms/step - loss: 0.1799 - val_loss: 0.1793
#
# Epoch 00014: val_loss did not improve from 0.15774
# Epoch 15/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1781 - val_loss: 0.1648
#
# Epoch 00015: val_loss did not improve from 0.15774
# Epoch 16/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1720 - val_loss: 0.1585
#
# Epoch 00016: val_loss did not improve from 0.15774
# Epoch 17/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1686 - val_loss: 0.1521
#
# Epoch 00017: val_loss improved from 0.15774 to 0.15212, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 18/150
# 50/50 [==============================] - 21s 414ms/step - loss: 0.1715 - val_loss: 0.1508
#
# Epoch 00018: val_loss improved from 0.15212 to 0.15076, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 19/150
# 50/50 [==============================] - 21s 414ms/step - loss: 0.1474 - val_loss: 0.2087
#
# Epoch 00019: val_loss did not improve from 0.15076
# Epoch 20/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1876 - val_loss: 0.1575
#
# Epoch 00020: val_loss did not improve from 0.15076
# Epoch 21/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1740 - val_loss: 0.1544
#
# Epoch 00021: val_loss did not improve from 0.15076
# Epoch 22/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1672 - val_loss: 0.1518
#
# Epoch 00022: val_loss did not improve from 0.15076
# Epoch 23/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1447 - val_loss: 0.1510
#
# Epoch 00023: val_loss did not improve from 0.15076
# Epoch 24/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1539 - val_loss: 0.1471
#
# Epoch 00024: val_loss improved from 0.15076 to 0.14708, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 25/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1597 - val_loss: 0.1730
#
# Epoch 00025: val_loss did not improve from 0.14708
# Epoch 26/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1657 - val_loss: 0.1592
#
# Epoch 00026: val_loss did not improve from 0.14708
# Epoch 27/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1554 - val_loss: 0.1578
#
# Epoch 00027: val_loss did not improve from 0.14708
# Epoch 28/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1509 - val_loss: 0.1443
#
# Epoch 00028: val_loss improved from 0.14708 to 0.14425, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 29/150
# 50/50 [==============================] - 21s 415ms/step - loss: 0.1487 - val_loss: 0.1452
#
# Epoch 00029: val_loss did not improve from 0.14425
# Epoch 30/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1496 - val_loss: 0.1493
#
# Epoch 00030: val_loss did not improve from 0.14425
# Epoch 31/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1494 - val_loss: 0.1539
#
# Epoch 00031: val_loss did not improve from 0.14425
# Epoch 32/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1553 - val_loss: 0.1549
#
# Epoch 00032: val_loss did not improve from 0.14425
# Epoch 33/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1486 - val_loss: 0.1508
#
# Epoch 00033: val_loss did not improve from 0.14425
# Epoch 34/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1573 - val_loss: 0.1609
#
# Epoch 00034: val_loss did not improve from 0.14425
# Epoch 35/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1517 - val_loss: 0.1429
#
# Epoch 00035: val_loss improved from 0.14425 to 0.14292, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 36/150
# 50/50 [==============================] - 21s 415ms/step - loss: 0.1431 - val_loss: 0.1427
#
# Epoch 00036: val_loss improved from 0.14292 to 0.14266, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 37/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1460 - val_loss: 0.1399
#
# Epoch 00037: val_loss improved from 0.14266 to 0.13986, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 38/150
# 50/50 [==============================] - 21s 415ms/step - loss: 0.1398 - val_loss: 0.1368
#
# Epoch 00038: val_loss improved from 0.13986 to 0.13677, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 39/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1268 - val_loss: 0.1494
#
# Epoch 00039: val_loss did not improve from 0.13677
# Epoch 40/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1387 - val_loss: 0.1903
#
# Epoch 00040: val_loss did not improve from 0.13677
# Epoch 41/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1450 - val_loss: 0.1371
#
# Epoch 00041: val_loss did not improve from 0.13677
# Epoch 42/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1461 - val_loss: 0.1498
#
# Epoch 00042: val_loss did not improve from 0.13677
# Epoch 43/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1502 - val_loss: 0.1410
#
# Epoch 00043: val_loss did not improve from 0.13677
# Epoch 44/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1402 - val_loss: 0.1295
#
# Epoch 00044: val_loss improved from 0.13677 to 0.12945, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 45/150
# 50/50 [==============================] - 21s 414ms/step - loss: 0.1317 - val_loss: 0.1412
#
# Epoch 00045: val_loss did not improve from 0.12945
# Epoch 46/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1340 - val_loss: 0.1297
#
# Epoch 00046: val_loss did not improve from 0.12945
# Epoch 47/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1399 - val_loss: 0.1597
#
# Epoch 00047: val_loss did not improve from 0.12945
# Epoch 48/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1427 - val_loss: 0.1401
#
# Epoch 00048: val_loss did not improve from 0.12945
# Epoch 49/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1326 - val_loss: 0.1251
#
# Epoch 00049: val_loss improved from 0.12945 to 0.12510, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 50/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1284 - val_loss: 0.1355
#
# Epoch 00050: val_loss did not improve from 0.12510
# Epoch 51/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1375 - val_loss: 0.1375
#
# Epoch 00051: val_loss did not improve from 0.12510
# Epoch 52/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1295 - val_loss: 0.1288
#
# Epoch 00052: val_loss did not improve from 0.12510
# Epoch 53/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1402 - val_loss: 0.1254
#
# Epoch 00053: val_loss did not improve from 0.12510
# Epoch 54/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1333 - val_loss: 0.1244
#
# Epoch 00054: val_loss improved from 0.12510 to 0.12442, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 55/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1240 - val_loss: 0.1252
#
# Epoch 00055: val_loss did not improve from 0.12442
# Epoch 56/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1278 - val_loss: 0.1273
#
# Epoch 00056: val_loss did not improve from 0.12442
# Epoch 57/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1283 - val_loss: 0.1285
#
# Epoch 00057: val_loss did not improve from 0.12442
# Epoch 58/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1327 - val_loss: 0.1393
#
# Epoch 00058: val_loss did not improve from 0.12442
# Epoch 59/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1295 - val_loss: 0.1221
#
# Epoch 00059: val_loss improved from 0.12442 to 0.12206, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 60/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1238 - val_loss: 0.1265
#
# Epoch 00060: val_loss did not improve from 0.12206
# Epoch 61/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1311 - val_loss: 0.1343
#
# Epoch 00061: val_loss did not improve from 0.12206
# Epoch 62/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1284 - val_loss: 0.1296
#
# Epoch 00062: val_loss did not improve from 0.12206
# Epoch 63/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1278 - val_loss: 0.1222
#
# Epoch 00063: val_loss did not improve from 0.12206
# Epoch 64/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1319 - val_loss: 0.1242
#
# Epoch 00064: val_loss did not improve from 0.12206
# Epoch 65/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1154 - val_loss: 0.1280
#
# Epoch 00065: val_loss did not improve from 0.12206
# Epoch 66/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1303 - val_loss: 0.1260
#
# Epoch 00066: val_loss did not improve from 0.12206
# Epoch 67/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1246 - val_loss: 0.1250
#
# Epoch 00067: val_loss did not improve from 0.12206
# Epoch 68/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1202 - val_loss: 0.1212
#
# Epoch 00068: val_loss improved from 0.12206 to 0.12123, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 69/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1297 - val_loss: 0.1252
#
# Epoch 00069: val_loss did not improve from 0.12123
# Epoch 70/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1226 - val_loss: 0.1277
#
# Epoch 00070: val_loss did not improve from 0.12123
# Epoch 71/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1264 - val_loss: 0.1233
#
# Epoch 00071: val_loss did not improve from 0.12123
# Epoch 72/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1213 - val_loss: 0.1207
#
# Epoch 00072: val_loss improved from 0.12123 to 0.12072, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 73/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1318 - val_loss: 0.1245
#
# Epoch 00073: val_loss did not improve from 0.12072
# Epoch 74/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1285 - val_loss: 0.1185
#
# Epoch 00074: val_loss improved from 0.12072 to 0.11846, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 75/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1226 - val_loss: 0.1137
#
# Epoch 00075: val_loss improved from 0.11846 to 0.11367, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 76/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1220 - val_loss: 0.1324
#
# Epoch 00076: val_loss did not improve from 0.11367
# Epoch 77/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1276 - val_loss: 0.1220
#
# Epoch 00077: val_loss did not improve from 0.11367
# Epoch 78/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1167 - val_loss: 0.1155
#
# Epoch 00078: val_loss did not improve from 0.11367
# Epoch 79/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1269 - val_loss: 0.1197
#
# Epoch 00079: val_loss did not improve from 0.11367
# Epoch 80/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1207 - val_loss: 0.1238
#
# Epoch 00080: val_loss did not improve from 0.11367
# Epoch 81/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1221 - val_loss: 0.1210
#
# Epoch 00081: val_loss did not improve from 0.11367
# Epoch 82/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1162 - val_loss: 0.1215
#
# Epoch 00082: val_loss did not improve from 0.11367
# Epoch 83/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1283 - val_loss: 0.1174
#
# Epoch 00083: val_loss did not improve from 0.11367
# Epoch 84/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1153 - val_loss: 0.1124
#
# Epoch 00084: val_loss improved from 0.11367 to 0.11235, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 85/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1233 - val_loss: 0.1168
#
# Epoch 00085: val_loss did not improve from 0.11235
# Epoch 86/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1231 - val_loss: 0.1182
#
# Epoch 00086: val_loss did not improve from 0.11235
# Epoch 87/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1148 - val_loss: 0.1146
#
# Epoch 00087: val_loss did not improve from 0.11235
# Epoch 88/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1212 - val_loss: 0.1172
#
# Epoch 00088: val_loss did not improve from 0.11235
# Epoch 89/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1121 - val_loss: 0.1151
#
# Epoch 00089: val_loss did not improve from 0.11235
# Epoch 90/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1160 - val_loss: 0.1129
#
# Epoch 00090: val_loss did not improve from 0.11235
# Epoch 91/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1262 - val_loss: 0.1149
#
# Epoch 00091: val_loss did not improve from 0.11235
# Epoch 92/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1159 - val_loss: 0.1144
#
# Epoch 00092: val_loss did not improve from 0.11235
# Epoch 93/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1141 - val_loss: 0.1129
#
# Epoch 00093: val_loss did not improve from 0.11235
# Epoch 94/150
# 50/50 [==============================] - 21s 410ms/step - loss: 0.1211 - val_loss: 0.1144
#
# Epoch 00094: val_loss did not improve from 0.11235
# Epoch 95/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1093 - val_loss: 0.1140
#
# Epoch 00095: val_loss did not improve from 0.11235
# Epoch 96/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1147 - val_loss: 0.1223
#
# Epoch 00096: val_loss did not improve from 0.11235
# Epoch 97/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1160 - val_loss: 0.1103
#
# Epoch 00097: val_loss improved from 0.11235 to 0.11031, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 98/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1098 - val_loss: 0.1218
#
# Epoch 00098: val_loss did not improve from 0.11031
# Epoch 99/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1118 - val_loss: 0.1214
#
# Epoch 00099: val_loss did not improve from 0.11031
# Epoch 100/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1152 - val_loss: 0.1131
#
# Epoch 00100: val_loss did not improve from 0.11031
# Epoch 101/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1136 - val_loss: 0.1155
#
# Epoch 00101: val_loss did not improve from 0.11031
# Epoch 102/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1113 - val_loss: 0.1103
#
# Epoch 00102: val_loss improved from 0.11031 to 0.11030, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 103/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1182 - val_loss: 0.1348
#
# Epoch 00103: val_loss did not improve from 0.11030
# Epoch 104/150
# 50/50 [==============================] - 21s 410ms/step - loss: 0.1130 - val_loss: 0.1110
#
# Epoch 00104: val_loss did not improve from 0.11030
# Epoch 105/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1040 - val_loss: 0.1089
#
# Epoch 00105: val_loss improved from 0.11030 to 0.10890, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 106/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1082 - val_loss: 0.1106
#
# Epoch 00106: val_loss did not improve from 0.10890
# Epoch 107/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1160 - val_loss: 0.1093
#
# Epoch 00107: val_loss did not improve from 0.10890
# Epoch 108/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1103 - val_loss: 0.1113
#
# Epoch 00108: val_loss did not improve from 0.10890
# Epoch 109/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1073 - val_loss: 0.1159
#
# Epoch 00109: val_loss did not improve from 0.10890
# Epoch 110/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1093 - val_loss: 0.1118
#
# Epoch 00110: val_loss did not improve from 0.10890
# Epoch 111/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1084 - val_loss: 0.1098
#
# Epoch 00111: val_loss did not improve from 0.10890
# Epoch 112/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1108 - val_loss: 0.1169
#
# Epoch 00112: val_loss did not improve from 0.10890
# Epoch 113/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1130 - val_loss: 0.1055
#
# Epoch 00113: val_loss improved from 0.10890 to 0.10549, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 114/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1134 - val_loss: 0.1079
#
# Epoch 00114: val_loss did not improve from 0.10549
# Epoch 115/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1093 - val_loss: 0.1140
#
# Epoch 00115: val_loss did not improve from 0.10549
# Epoch 116/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1080 - val_loss: 0.1069
#
# Epoch 00116: val_loss did not improve from 0.10549
# Epoch 117/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1062 - val_loss: 0.1172
#
# Epoch 00117: val_loss did not improve from 0.10549
# Epoch 118/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1118 - val_loss: 0.1097
#
# Epoch 00118: val_loss did not improve from 0.10549
# Epoch 119/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1036 - val_loss: 0.1072
#
# Epoch 00119: val_loss did not improve from 0.10549
# Epoch 120/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1136 - val_loss: 0.1064
#
# Epoch 00120: val_loss did not improve from 0.10549
# Epoch 121/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1076 - val_loss: 0.1046
#
# Epoch 00121: val_loss improved from 0.10549 to 0.10458, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 122/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1086 - val_loss: 0.1082
#
# Epoch 00122: val_loss did not improve from 0.10458
# Epoch 123/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1082 - val_loss: 0.1099
#
# Epoch 00123: val_loss did not improve from 0.10458
# Epoch 124/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1096 - val_loss: 0.1079
#
# Epoch 00124: val_loss did not improve from 0.10458
# Epoch 125/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1050 - val_loss: 0.1049
#
# Epoch 00125: val_loss did not improve from 0.10458
# Epoch 126/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1074 - val_loss: 0.1080
#
# Epoch 00126: val_loss did not improve from 0.10458
# Epoch 127/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1094 - val_loss: 0.1098
#
# Epoch 00127: val_loss did not improve from 0.10458
# Epoch 128/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1131 - val_loss: 0.1067
#
# Epoch 00128: val_loss did not improve from 0.10458
# Epoch 129/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1069 - val_loss: 0.1054
#
# Epoch 00129: val_loss did not improve from 0.10458
# Epoch 130/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1043 - val_loss: 0.1076
#
# Epoch 00130: val_loss did not improve from 0.10458
# Epoch 131/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1011 - val_loss: 0.1021
#
# Epoch 00131: val_loss improved from 0.10458 to 0.10215, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 132/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1157 - val_loss: 0.1118
#
# Epoch 00132: val_loss did not improve from 0.10215
# Epoch 133/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1100 - val_loss: 0.1306
#
# Epoch 00133: val_loss did not improve from 0.10215
# Epoch 134/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1130 - val_loss: 0.1033
#
# Epoch 00134: val_loss did not improve from 0.10215
# Epoch 135/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1090 - val_loss: 0.1057
#
# Epoch 00135: val_loss did not improve from 0.10215
# Epoch 136/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1078 - val_loss: 0.1118
#
# Epoch 00136: val_loss did not improve from 0.10215
# Epoch 137/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1001 - val_loss: 0.1124
#
# Epoch 00137: val_loss did not improve from 0.10215
# Epoch 138/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1033 - val_loss: 0.1101
#
# Epoch 00138: val_loss did not improve from 0.10215
# Epoch 139/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1048 - val_loss: 0.1079
#
# Epoch 00139: val_loss did not improve from 0.10215
# Epoch 140/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1169 - val_loss: 0.1082
#
# Epoch 00140: val_loss did not improve from 0.10215
# Epoch 141/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1111 - val_loss: 0.1037
#
# Epoch 00141: val_loss did not improve from 0.10215
# Epoch 142/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1075 - val_loss: 0.1029
#
# Epoch 00142: val_loss did not improve from 0.10215
# Epoch 143/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1107 - val_loss: 0.1045
#
# Epoch 00143: val_loss did not improve from 0.10215
# Epoch 144/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1084 - val_loss: 0.1044
#
# Epoch 00144: val_loss did not improve from 0.10215
# Epoch 145/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.0985 - val_loss: 0.1033
#
# Epoch 00145: val_loss did not improve from 0.10215
# Epoch 146/150
# 50/50 [==============================] - 21s 412ms/step - loss: 0.1050 - val_loss: 0.1015
#
# Epoch 00146: val_loss improved from 0.10215 to 0.10151, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 147/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1037 - val_loss: 0.1046
#
# Epoch 00147: val_loss did not improve from 0.10151
# Epoch 148/150
# 50/50 [==============================] - 21s 411ms/step - loss: 0.1064 - val_loss: 0.1004
#
# Epoch 00148: val_loss improved from 0.10151 to 0.10042, saving model to /content/drive/MyDrive/Dense_depth/Training/DenseDepth.ckpt
# Epoch 149/150
# 50/50 [==============================] - 21s 413ms/step - loss: 0.1041 - val_loss: 0.1067
#
# Epoch 00149: val_loss did not improve from 0.10042
# Epoch 150/150
# 50/50 [==============================] - 20s 410ms/step - loss: 0.1096 - val_loss: 0.1027
#
# Epoch 00150: val_loss did not improve from 0.10042

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 8))

plt.plot(epochs_range, loss, label='Training loss')
plt.plot(epochs_range, val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Loss | Batch size = ' + str(batch_size) + ', steps_per_epoch = ' + str(train_steps) + ', validation_steps = ' + str(val_steps))
plt.xlabel('epochs')
os.chdir(SAVE_PATH)
plt.savefig('loss.png')

# %% [markdown]
# # Test Helper functions

# %% [markdown]
# ## Utils

# %%
import cv2
import numpy as np

def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %% [markdown]
# # Test

# %%
os.chdir(SAVE_PATH)
print('Loading model...')
model = DenseDepth()
checkpoint_path = "Training/DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# Model weights loaded.

# %%
count = 3

os.chdir(SAVE_PATH)
path_pre = DATA_PATH + 'data/nyu2_test/'
files = [f for f in os.listdir(path_pre) if f.split('_')[1] == 'colors.png']
(fig, axes) = plt.subplots(nrows=count, ncols=3, figsize=(15,15))
i = 0
for f in files:
    file_id = f.split('_')[0]
    depth_file = file_id + '_depth.png'
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('RGB')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('Predicted')

    img = cv2.imread(path_pre + depth_file, cv2.IMREAD_ANYDEPTH)
    axes[i][1].imshow(img, cmap='plasma')
    axes[i][1].set_title('Ground Truth')
    
    if i == count-1:
        break
    else:
        i += 1

plt.savefig('result.png')

# %% [markdown]
# # Evaluation

# %%
from evaluate import load_test_data, evaluate

rgb, depth, crop = load_test_data()
evaluate(model, rgb, depth, crop)
# Out:
# Loading test data...Test data loaded.
#
#         a1,         a2,         a3,        rel,        rms,     log_10
#     0.8114,     0.9648,     0.9925,     0.1429,     0.5059,     0.0601
